# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt =  f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the following outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
initial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# {'title': 'Rise of AI in India', 'outline': [{'type': 'text', 'text': 'Here is a comprehensive and detailed blog outline on the topic **"The Rise of AI in India: Innovation, Impact, and the Future."**\n\n---\n\n# Blog Outline: The Rise of AI in India: Innovation, Impact, and the Future\n\n## I. Introduction\n*   **The Hook:** Start with a compelling stat or visual (e.g., India’s rapid leap from an IT back-office to a global AI innovation hub).\n*   **Defining the Moment:** Briefly touch upon the convergence of widespread internet access (cheap data), a massive tech talent pool, and government backing driving the current AI boom in India.\n*   **Thesis Statement:** India is not just a consumer of Artificial Intelligence, but a major creator, positioning itself to shape the global AI landscape over the next decade.\n\n## II. The Catalysts: Why is AI Booming in India Right Now?\n*   **Massive Digital Infrastructure (India Stack):** \n    *   Aadhaar, UPI, and DigiLocker generating petabytes of structured data.\n    *   Low-cost mobile data making AI-driven apps accessible to millions.\n*   **Demographic Dividend:**\n    *   World’s largest youth population.\n    *   Millions of STEM graduates entering the workforce annually.\n*   **Government Policy and Vision:**\n    *   *IndiaAI Mission:* Financial outlay for compute capacity, startups, and safe AI.\n    *   National Strategy for AI ("AI for All" philosophy).\n\n## III. Sector-by-Sector Transformation (Where AI is Making Waves)\n*   **Agriculture (AgriTech):**\n    *   Predictive analytics for weather and crop yields.\n    *   AI-powered drones for pest control and soil health monitoring (e.g., startups like CropIn).\n*   **Healthcare:**\n    *   Bridging the doctor-to-patient ratio gap in rural areas.\n    *   AI in early diagnostics (tuberculosis, diabetic retinopathy, cancer screening).\n*   **Fintech & Banking:**\n    *   Fraud detection and real-time risk assessment.\n    *   Hyper-personalized financial services powered by Vernacular LLMs (Large Language Models).\n*   **Education (EdTech):**\n    *   Adaptive learning platforms tailoring content to individual student paces.\n    *   AI tutors overcoming language barriers in tier-2 and tier-3 cities.\n\n## IV. Made in India: Vernacular AI and Indigenous Models\n*   **Breaking the English Barrier:** \n    *   Overcoming the challenge of India\'s linguistic diversity (22 official languages).\n*   **Key Players & Initiatives:**\n    *   *Bhashini:* The government’s AI-led language translation mission.\n    *   Indigenous LLMs like Sarvam AI, Krutrim (Ola), and Tech Mahindra’s Project Indus.\n*   **Open-Source & Jugaad Innovation:** How Indian developers are building cost-effective, high-impact AI solutions.\n\n## V. The Challenges & Roadblocks\n*   **The Infrastructure Gap:**\n    *   Lack of domestic high-performance computing (GPUs) and massive data centers compared to the US and China.\n*   **Talent Drain vs. Talent Gain:**\n    *   The "Brain Drain" of top AI researchers to Silicon Valley vs. the return of diaspora talent.\n*   **Ethical Concerns & Data Privacy:**\n    *   Implementation of the Digital Personal Data Protection (DPDP) Act.\n    *   Mitigating algorithmic bias in a culturally diverse society.\n*   **Job Displacement vs. Creation:**\n    *   The looming threat to traditional IT/BPO jobs and the urgent need for massive upskilling.\n\n## VI. The Future Horizon: What to Expect by 2030\n*   **Economic Impact:** Estimates of AI adding hundreds of billions to India’s GDP.\n*   **AI for Social Good:** Using AI to solve localized problems (traffic management, disaster prediction, clean energy).\n*   **Global South Leadership:** India positioning itself as the voice and ethical guide for AI development in developing nations.\n\n## VII. Conclusion\n*   **Summary:** Reiterate that India’s AI rise is powered by a unique blend of government vision, startup agility, and societal need.\n*   **Final Thought:** AI in India i ...

# %%
print(final_state['outline'][0]['text'])
# Out:
# Here is a comprehensive and detailed blog outline on the topic **"The Rise of AI in India: Innovation, Impact, and the Future."**
#
# ---
#
# # Blog Outline: The Rise of AI in India: Innovation, Impact, and the Future
#
# ## I. Introduction
# *   **The Hook:** Start with a compelling stat or visual (e.g., India’s rapid leap from an IT back-office to a global AI innovation hub).
# *   **Defining the Moment:** Briefly touch upon the convergence of widespread internet access (cheap data), a massive tech talent pool, and government backing driving the current AI boom in India.
# *   **Thesis Statement:** India is not just a consumer of Artificial Intelligence, but a major creator, positioning itself to shape the global AI landscape over the next decade.
#
# ## II. The Catalysts: Why is AI Booming in India Right Now?
# *   **Massive Digital Infrastructure (India Stack):**
#     *   Aadhaar, UPI, and DigiLocker generating petabytes of structured data.
#     *   Low-cost mobile data making AI-driven apps accessible to millions.
# *   **Demographic Dividend:**
#     *   World’s largest youth population.
#     *   Millions of STEM graduates entering the workforce annually.
# *   **Government Policy and Vision:**
#     *   *IndiaAI Mission:* Financial outlay for compute capacity, startups, and safe AI.
#     *   National Strategy for AI ("AI for All" philosophy).
#
# ## III. Sector-by-Sector Transformation (Where AI is Making Waves)
# *   **Agriculture (AgriTech):**
#     *   Predictive analytics for weather and crop yields.
#     *   AI-powered drones for pest control and soil health monitoring (e.g., startups like CropIn).
# *   **Healthcare:**
#     *   Bridging the doctor-to-patient ratio gap in rural areas.
#     *   AI in early diagnostics (tuberculosis, diabetic retinopathy, cancer screening).
# *   **Fintech & Banking:**
#     *   Fraud detection and real-time risk assessment.
#     *   Hyper-personalized financial services powered by Vernacular LLMs (Large Language Models).
# *   **Education (EdTech):**
#     *   Adaptive learning platforms tailoring content to individual student paces.
#     *   AI tutors overcoming language barriers in tier-2 and tier-3 cities.
#
# ## IV. Made in India: Vernacular AI and Indigenous Models
# *   **Breaking the English Barrier:**
#     *   Overcoming the challenge of India's linguistic diversity (22 official languages).
# *   **Key Players & Initiatives:**
#     *   *Bhashini:* The government’s AI-led language translation mission.
#     *   Indigenous LLMs like Sarvam AI, Krutrim (Ola), and Tech Mahindra’s Project Indus.
# *   **Open-Source & Jugaad Innovation:** How Indian developers are building cost-effective, high-impact AI solutions.
#
# ## V. The Challenges & Roadblocks
# *   **The Infrastructure Gap:**
#     *   Lack of domestic high-performance computing (GPUs) and massive data centers compared to the US and China.
# *   **Talent Drain vs. Talent Gain:**
#     *   The "Brain Drain" of top AI researchers to Silicon Valley vs. the return of diaspora talent.
# *   **Ethical Concerns & Data Privacy:**
#     *   Implementation of the Digital Personal Data Protection (DPDP) Act.
#     *   Mitigating algorithmic bias in a culturally diverse society.
# *   **Job Displacement vs. Creation:**
#     *   The looming threat to traditional IT/BPO jobs and the urgent need for massive upskilling.
#
# ## VI. The Future Horizon: What to Expect by 2030
# *   **Economic Impact:** Estimates of AI adding hundreds of billions to India’s GDP.
# *   **AI for Social Good:** Using AI to solve localized problems (traffic management, disaster prediction, clean energy).
# *   **Global South Leadership:** India positioning itself as the voice and ethical guide for AI development in developing nations.
#
# ## VII. Conclusion
# *   **Summary:** Reiterate that India’s AI rise is powered by a unique blend of government vision, startup agility, and societal need.
# *   **Final Thought:** AI in India is not merely about technological advancement; it is a tool for inclusive growth and socioeconomic upliftment.
# *   **Call to Action (CTA):**
#     *   *Prompt for readers:* "How is your industry using AI? Are you optimistic or cautious about India's AI future? Share your thoughts in the comments below."
#     *   *Share/Subscribe buttons.*
#
# ---
#
# ### **Tips for Writing This Blog:**
# *   **Tone:** Optimistic, forward-looking, yet grounded in reality (acknowledging challenges).
# *   **Visuals to Include:** Infographics on India's data consumption, screenshots of Indian AI startups in action, or a map showing regional language AI adoption.
# *   **Internal/External Links:** Link to the official *IndiaAI* portal, recent Gartner reports on AI in India, and relevant case studies.

# %%
print(final_state['content'][0]['text'])
# Out:
# # The Rise of AI in India: Innovation, Impact, and the Future
#
# ## I. Introduction
#
# Remember when India was primarily viewed as the world’s IT back-office—a destination for outsourced customer support and basic software maintenance? Fast forward to today, and that narrative has completely flipped. India has rapidly evolved into a global powerhouse for Artificial Intelligence (AI) innovation, moving from a consumer of technology to a principal creator.
#
# This explosive growth is not an accident. It is the result of a unique convergence: widespread internet access fueled by some of the cheapest mobile data on the planet, a massive, highly skilled tech talent pool, and aggressive government backing. Today, India is not just adapting to the global AI wave; it is positioning itself to shape the very landscape of artificial intelligence over the next decade.
#
# ---
#
# ## II. The Catalysts: Why is AI Booming in India Right Now?
#
# Several foundational pillars have come together to create the perfect environment for an AI revolution in India.
#
# ### 1. Massive Digital Infrastructure (India Stack)
# Long before the current generative AI boom, India laid the groundwork with the "India Stack"—a public digital infrastructure comprising Aadhaar (digital identity), UPI (unified payments interface), and DigiLocker. This system generates petabytes of structured data daily. Combined with ultra-low-cost mobile data, millions of Indians are interacting with digital platforms daily, feeding the data engines necessary to train localized AI models.
#
# ### 2. Demographic Dividend
# India boasts the world's largest youth population, with millions of STEM (Science, Technology, Engineering, and Math) graduates entering the workforce annually. This young, tech-native generation is uniquely positioned to build, deploy, and scale AI solutions faster than almost anywhere else in the world.
#
# ### 3. Government Policy and Vision
# The Indian government has recognized AI as a strategic asset for economic growth and national security.
# * **The IndiaAI Mission:** A substantial financial outlay designed to build domestic compute capacity, fund AI startups, and ensure safe, ethical AI deployment.
# * **"AI for All":** The guiding philosophy of the National Strategy for AI, which emphasizes deploying artificial intelligence to solve socio-economic challenges in healthcare, agriculture, and education rather than just focusing on commercial profits.
#
# ---
#
# ## III. Sector-by-Sector Transformation (Where AI is Making Waves)
#
# Artificial intelligence in India isn't confined to tech parks in Bengaluru; it is transforming ground-level realities across core industries.
#
# ### 1. Agriculture (AgriTech)
# Agriculture employs a massive portion of India’s workforce. Startups like CropIn are leveraging AI-powered drones, IoT sensors, and predictive analytics to give farmers hyper-local weather forecasts, real-time pest control advice, and soil health monitoring. This helps mitigate the risks of unpredictable monsoons and maximizes crop yields.
#
# ### 2. Healthcare
# With a skewed doctor-to-patient ratio—especially in rural areas—AI is stepping in as a force multiplier. AI-powered diagnostic tools are enabling early detection of conditions like tuberculosis, diabetic retinopathy, and various forms of cancer via mobile X-rays and retinal scans, bringing quality healthcare to remote villages where specialists are scarce.
#
# ### 3. Fintech & Banking
# India’s fintech ecosystem is one of the most advanced globally, largely thanks to UPI. Financial institutions are using AI for real-time risk assessment, automated fraud detection, and hyper-personalized financial services. Furthermore, Vernacular Large Language Models (LLMs) are helping banks serve customers in tier-2 and tier-3 cities in their native languages.
#
# ### 4. Education (EdTech)
# Education in India has long struggled with a "one-size-fits-all" approach. AI-driven adaptive learning platforms are now tailoring content to individual student paces, identifying learning gaps, and providing AI tutors that break down language barriers for students outside metropolitan hubs.
#
# ---
#
# ## IV. Made in India: Vernacular AI and Indigenous Models
#
# One of the most exciting aspects of India's AI rise is the conscious effort to build solutions tailored to its unique cultural and linguistic diversity.
#
# ### Breaking the English Barrier
# With 22 official languages and hundreds of dialects, treating English as the default tech language leaves out a vast majority of the population. India's AI ecosystem is actively solving this through vernacular AI.
#
# ### Key Players & Initiatives
# * **Bhashini:** A government-backed AI-led language translation mission designed to break down language barriers and create an open-source repository of Indian language datasets.
# * **Indigenous LLMs:** Homegrown models like Sarvam AI, Ola’s Krutrim, and Tech Mahindra’s Project Indus are building foundation models specifically trained on Indian languages, cultural contexts, and data nuances.
# * **Open-Source & Jugaad Innovation:** True to the spirit of *jugaad* (resourceful innovation), Indian developers are building highly cost-effective, high-impact AI solutions that do millions of transactions on a fraction of the computing power used by their Western counterparts.
#
# ---
#
# ## V. The Challenges & Roadblocks
#
# Despite the massive momentum, the road ahead is not without hurdles.
#
# ### 1. The Infrastructure Gap
# India faces a deficit in domestic high-performance computing (GPUs) and massive data centers compared to global superpowers like the US and China. Building foundational models requires immense computational power, much of which currently relies on foreign cloud infrastructure.
#
# ### 2. Talent Drain vs. Talent Gain
# While India produces millions of engineers, the "Brain Drain" of top-tier AI researchers to Silicon Valley remains a challenge. However, a reverse trend is also emerging, with top talent returning to India to lead local AI labs and startups.
#
# ### 3. Ethical Concerns & Data Privacy
# As AI scales, questions around data privacy and algorithmic bias take center stage. The implementation of the Digital Personal Data Protection (DPDP) Act is a step forward, but mitigating bias in a culturally, religiously, and economically diverse society remains an ongoing challenge.
#
# ### 4. Job Displacement vs. Creation
# The traditional Indian IT services and BPO sectors face an existential threat from automation. Upskilling millions of IT professionals to transition from routine coding and support to high-value AI architecture and prompt engineering is an urgent national priority.
#
# ---
#
# ## VI. The Future Horizon: What to Expect by 2030
#
# As we look toward the end of the decade, the trajectory of AI in India points toward massive socio-economic integration.
#
# * **Economic Impact:** Industry reports estimate that AI could add hundreds of billions of dollars to India’s GDP by 2030, serving as a primary engine for reaching a $5 trillion economy.
# * **AI for Social Good:** Beyond commerce, AI will increasingly tackle localized urban and rural problems—from managing chaotic metropolitan traffic to predicting natural disasters and optimizing clean energy grids.
# * **Global South Leadership:** By focusing on inclusive, ethical, and frugal AI, India is positioning itself as the voice and ethical guide for AI development in other developing nations across the Global South.
#
# ---
#
# ## VII. Conclusion
#
# The rise of AI in India is far more than a technological upgrade; it is a profound socio-economic transformation. Powered by a unique blend of visionary government policies, relentless startup agility, and deep societal need, India is proving that the future of AI isn't just being coded in Silicon Valley—it is being built, tested, and scaled in the streets of Bengaluru, Hyderabad, and rural villages alike.
#
# AI in India is ultimately a tool for inclusive growth, ensuring that technological advancement leaves no one behind.
#
# ***
#
# ### What do you think?
# How is your industry using AI? Are you optimistic or cautious about India's AI future? **Share your thoughts in the comments below!**
#
# *[Share Button]* | *[Subscribe for More Insights]*
