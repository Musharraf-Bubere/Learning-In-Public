# %% [markdown]
# # Embedding Techniques

# %%
import os
from dotenv import load_dotenv
load_dotenv()  # Load all the environment variables
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import OpenAIEmbeddings
embeddings=OpenAIEmbeddings(model="text-embedding-3-large")
embeddings
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[9], line 2
#       1 from langchain_openai import OpenAIEmbeddings
# ----> 2 embeddings=OpenAIEmbeddings(model="text-embedding-3-large")
#       3 embeddings
#
#     [... skipping hidden 1 frame]
#
# File d:\Learning-In-Public\Generative_AI\langc_env\lib\site-packages\langchain_openai\embeddings\base.py:436, in OpenAIEmbeddings.validate_environment(self)
#     431             self.http_client = httpx.Client(proxy=self.openai_proxy)
#     432         sync_specific = {
#     433             "http_client": self.http_client,
#     434             "api_key": sync_api_key_value,
#     435         }
# --> 436         self.client = openai.OpenAI(**client_params, **sync_specific).embeddings  # type: ignore[arg-type]
#     437 if not self.async_client:
#     438     if self.openai_proxy and not self.http_async_client:
#
# File d:\Learning-In-Public\Generative_AI\langc_env\lib\site-packages\openai\_client.py:229, in OpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     219 self.admin_api_key = admin_api_key if provider_runtime is None else None
#     221 if (
#     222     provider_runtime is None
#     223     and _enforce_credentials
#    (...)
#     227     and self.admin_api_key is None
#     228 ):
# --> 229     raise OpenAIError(
#     230         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     231     )
#     233 if organization is None and provider_runtime is None:
#     234     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.

# %%
text="This is a tutorial on OPENAI embedding"
query_result=embeddings.embed_query(text)
query_result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 text="This is a tutorial on OPENAI embedding"
# ----> 2 query_result=embeddings.embed_query(text)
#       3 query_result
#
# NameError: name 'embeddings' is not defined

# %%
len(query_result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 len(query_result)
#
# NameError: name 'query_result' is not defined

# %%
embeddings_1024=embeddings=OpenAIEmbeddings(model="text-embedding-3-large",dimensions=1024)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 embeddings_1024=embeddings=OpenAIEmbeddings(model="text-embedding-3-large",dimensions=1024)
#
#     [... skipping hidden 1 frame]
#
# File d:\Learning-In-Public\Generative_AI\langc_env\lib\site-packages\langchain_openai\embeddings\base.py:436, in OpenAIEmbeddings.validate_environment(self)
#     431             self.http_client = httpx.Client(proxy=self.openai_proxy)
#     432         sync_specific = {
#     433             "http_client": self.http_client,
#     434             "api_key": sync_api_key_value,
#     435         }
# --> 436         self.client = openai.OpenAI(**client_params, **sync_specific).embeddings  # type: ignore[arg-type]
#     437 if not self.async_client:
#     438     if self.openai_proxy and not self.http_async_client:
#
# File d:\Learning-In-Public\Generative_AI\langc_env\lib\site-packages\openai\_client.py:229, in OpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     219 self.admin_api_key = admin_api_key if provider_runtime is None else None
#     221 if (
#     222     provider_runtime is None
#     223     and _enforce_credentials
#    (...)
#     227     and self.admin_api_key is None
#     228 ):
# --> 229     raise OpenAIError(
#     230         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     231     )
#     233 if organization is None and provider_runtime is None:
#     234     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.

# %%
embeddings_1024

# %%
text="This is a tutorial on OPENAI embedding"
query_result=embeddings_1024.embed_query(text)
len(query_result)

# %%
query_result

# %%
from langchain_community.document_loaders import TextLoader

loader=TextLoader('speech.txt')
docs=loader.load()
docs

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter=RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
final_documents=text_splitter.split_documents(docs)
final_documents

# %%
## Vector Embedding And Vector StoreDB
from langchain_community.vectorstores import Chroma

db=Chroma.from_documents(final_documents,embeddings_1024)
db

# %%
### Retrieve the results from query vectorstore db
query="It will be all the easier for us to conduct ourselves as belligerents"
retrieved_results=db.similarity_search(query)
print(retrieved_results)
