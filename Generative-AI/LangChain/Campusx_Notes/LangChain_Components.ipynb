# %% [markdown]
# ### LangChain Components
#
# ![alt text](<Screenshot 2026-08-06 194957-1.png>)

# %% [markdown]
# ### 1. Models
#
# In LangChain, "models" are the core interfaces through which you interact with AI models.
#
# ![alt text](<Screenshot 2026-08-06 200317.png>)
# ![alt text](<Screenshot 2026-08-06 200650.png>)
# ![alt text](<Screenshot 2026-08-06 200910.png>)

# %% [markdown]
# ### 2. Prompts
#
# ![alt text](<Screenshot 2026-08-06 201222.png>)
# ![alt text](<Screenshot 2026-08-06 201346.png>)
# ![alt text](<Screenshot 2026-08-06 201616.png>)
# ![alt text](<Screenshot 2026-08-06 201752.png>)
